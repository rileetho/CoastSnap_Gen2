# %%
import requests

# change datum to MHHW

url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-01-01%2000%3A00&to=2024-01-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-02-01%2000%3A00&to=2024-02-29%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-03-01%2000%3A00&to=2024-03-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-04-01%2000%3A00&to=2024-04-30%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-05-01%2000%3A00&to=2024-05-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-06-01%2000%3A00&to=2024-06-30%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-07-01%2000%3A00&to=2024-07-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-08-01%2000%3A00&to=2024-08-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-09-01%2000%3A00&to=2024-09-30%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-10-01%2000%3A00&to=2024-10-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-11-01%2000%3A00&to=2024-11-30%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2024-12-01%2000%3A00&to=2024-12-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"
#url = "https://dashboard.hohonu.io/api/v1/stations/hohonu-162/waterlevel?from=2025-01-01%2000%3A00&to=2025-01-31%2023%3A59&units=metric&datum=NAVD&qc_level=1&flags=false&predictions=false"

headers = {
    "accept": "application/json",
    "Authorization": "aef15a8e2589b42d5ea5c10866aa61305993c65c"
}

response = requests.get(url, headers=headers)

#print(response.text)

# %%
from json import loads

# %%
dic = loads(response.text)

# %%
dic.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
import scipy

# %%
from scipy.io import savemat

# %%
#savemat('hohonu-162.mat',{'data':dic['data'][:-1]})

# %%
import numpy as np
np.where(dic['data'] == None)
# Out:
# (array([], dtype=int64),)

# %%
dic['data']['waterlevel'][:]
# Out:
# [{'t': '2024-01-01T00:00:00Z', 'o': -0.3},
#  {'t': '2024-01-01T00:06:00Z', 'o': -0.31},
#  {'t': '2024-01-01T00:12:00Z', 'o': -0.32},
#  {'t': '2024-01-01T00:18:00Z', 'o': -0.32},
#  {'t': '2024-01-01T00:24:00Z', 'o': -0.34},
#  {'t': '2024-01-01T00:30:00Z', 'o': -0.34},
#  {'t': '2024-01-01T00:36:00Z', 'o': -0.33},
#  {'t': '2024-01-01T00:42:00Z', 'o': -0.36},
#  {'t': '2024-01-01T00:48:00Z', 'o': -0.36},
#  {'t': '2024-01-01T00:54:00Z', 'o': -0.35},
#  {'t': '2024-01-01T01:00:00Z', 'o': -0.34},
#  {'t': '2024-01-01T01:06:00Z', 'o': -0.35},
#  {'t': '2024-01-01T01:12:00Z', 'o': -0.33},
#  {'t': '2024-01-01T01:18:00Z', 'o': -0.31},
#  {'t': '2024-01-01T01:24:00Z', 'o': -0.32},
#  {'t': '2024-01-01T01:30:00Z', 'o': -0.31},
#  {'t': '2024-01-01T01:36:00Z', 'o': -0.3},
#  {'t': '2024-01-01T01:42:00Z', 'o': -0.31},
#  {'t': '2024-01-01T01:48:00Z', 'o': -0.27},
#  {'t': '2024-01-01T01:54:00Z', 'o': -1.09},
#  {'t': '2024-01-01T02:00:00Z', 'o': -1.29},
# ...

# %%
np.array(dic['data'][:-2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 np.array(dic['data'][:-2])
#
# TypeError: unhashable type: 'slice'

# %%
tides = np.array(dic['data'][:-2][-1])
tides
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tides = np.array(dic['data'][:-2][-1])
#       2 tides
#
# TypeError: unhashable type: 'slice'

# %%
mask = np.where(np.isnan(tides.astype(float)) == False)[0]

# %%
times= np.array(dic['data'][:-2][0])
times[mask]

# %%
len(tides[mask])

# %%
tidedata = tides[mask]
timedata = times[mask]

# %%
savemat('hohonu-162-gmt_navd.mat',
        {'time':timedata,
         'level':tidedata})

#'hohonu-162-gmt_mhhw.mat'
