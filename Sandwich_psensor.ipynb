# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url = 'https://geoport.usgs.esipfed.org/thredds/dodsC/silt/usgs/Projects/stellwagen/CF-1.6/SANDWICH2017/10811whV-a.nc'
ds = xr.open_dataset(url)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 15212, z: 52)
# Coordinates:
#     latitude               float32 ...
#     longitude              float32 ...
#   * time                   (time) datetime64[ns] 2016-12-17T13:14:22 ... 2017...
#   * z                      (z) float32 -7.058 -6.758 -6.458 ... 7.942 8.242
# Data variables: (12/25)
#     feature_type_instance  |S64 ...
#     crs                    int32 ...
#     platform               int32 ...
#     Hdg_1215               (time) float32 ...
#     sensor_depth           float64 ...
#     Or                     (time) float32 ...
#     ...                     ...
#     Wvert                  (time, z) float32 ...
#     cor                    (time, z) float32 ...
#     corvert                (time, z) float32 ...
#     u_1205                 (time, z) float32 ...
#     v_1206                 (time, z) float32 ...
#     w_1204                 (time, z) float32 ...
# Attributes: (12/108)
# ...
